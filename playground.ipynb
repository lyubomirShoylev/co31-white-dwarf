# %%
import numpy as np
arr = np.array([[1,2],[3,4],[5,6]])
np.savetxt("test.csv", arr, delimiter=',')

# %%
file= pd.read_csv("test2.csv")
# df = file.iloc[999::1000, :]
# line = pd.DataFrame({'xdot': 0, 'x': 1}, index=[0])
# # concatenate two dataframe
# df2 = pd.concat([line,df]).reset_index(drop=True)
# plt.plot(df2.index, df2["x"])
plt.plot(file.index, file["x"])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(E6nonRelativ["NoIter"], E6nonRelativ["massSolMass"]/0.01)
plt.plot(E10nonRelativ["NoIter"], E10nonRelativ["massSolMass"])
plt.plot(E14nonRelativ["NoIter"], E14nonRelativ["massSolMass"]/150)
plt.xscale("log")
plt.show
plt.savefig("kewl.pdf")

# %%
plt.plot(E6Relativ["NoIter"], E6Relativ["massSolMass"])
plt.plot(E10Relativ["NoIter"], E10Relativ["massSolMass"])
plt.plot(E14Relativ["NoIter"], E14Relativ["massSolMass"])
plt.xscale("log")
plt.xlim(left=1e3)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
